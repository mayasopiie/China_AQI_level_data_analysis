# %%
import os, time, datetime, shutil, re
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

# %%
aqi_df = pd.read_csv('aqi_dataset.csv')
aqi_df.head()
# Out:
#    Unnamed: 0       station  year  month  day        date  PM2.5   PM10   SO2  \
# 0           0  Aotizhongxin  2013      3    1  2013-03-01    7.0   11.0  12.0
# 1           1  Aotizhongxin  2013      3    2  2013-03-02   31.0   42.0  37.0
# 2           2  Aotizhongxin  2013      3    3  2013-03-03   77.0  121.0  61.0
# 3           3  Aotizhongxin  2013      3    4  2013-03-04   23.0   45.0  23.0
# 4           4  Aotizhongxin  2013      3    5  2013-03-05  149.0  184.0  94.0
#
#      NO2      CO    O3  AQI_value                       AQI_label  \
# 0   23.0   429.0  64.0         32                            Good
# 1   67.0   825.0  30.0         84                        Moderate
# 2   81.0  1621.0  19.0        102  Unhealthy for Sensitive Groups
# 3   46.0   606.0  54.0         57                        Moderate
# 4  133.0  2358.0  68.0        199                       Unhealthy
#
#   highest_pollutant
# 0                O3
# 1               NO2
# 2             PM2.5
# 3               NO2
# 4             PM2.5

# %%
guanyuan_df = aqi_df[aqi_df['station'] == 'Guanyuan']
guanyuan_df.head()
# Out:
#   Cell In[3], line 2
#     guanyuan_df.head()
#     ^
# SyntaxError: invalid syntax
